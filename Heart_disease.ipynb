# %% [markdown]
# <a href="https://colab.research.google.com/github/SoundaryaDube/MIPM/blob/main/Heart_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
winson13_heart_disease_dataset_path = kagglehub.dataset_download('winson13/heart-disease-dataset')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/winson13/heart-disease-dataset?dataset_version_number=2...
# 100%|██████████| 25.2k/25.2k [00:00<00:00, 33.4MB/s]
# Extracting files...
# Data source import complete.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_path = '/content/drive/MyDrive/Heart Disease.zip'
extract_path = '/content/drive/MyDrive/'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
print("File extracted successfully!")
# Out:
# File extracted successfully!

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset Heart Disease.csv')

# %%
df.shape
# Out:
# (1048, 13)

# %%
df.head()
# Out:
#    Unnamed: 0  age  sex  chest pain type  resting bps  cholesterol  \
# 0           0   40    1                2          140        289.0
# 1           1   49    0                3          160        180.0
# 2           2   37    1                2          130        283.0
# 3           3   48    0                4          138        214.0
# 4           4   54    1                3          150        195.0
#
#    fasting blood sugar  resting ecg  max heart rate  exercise angina  oldpeak  \
# 0                    0            0             172                0      0.0
# 1                    0            0             156                0      1.0
# 2                    0            1              98                0      0.0
# 3                    0            0             108                1      1.5
# 4                    0            0             122                0      0.0
#
#    ST slope  target
# 0         1       0
# 1         2       1
# 2         1       0
# 3         2       1
# 4         1       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1048 non-null   int64
#  1   age                  1048 non-null   int64
#  2   sex                  1048 non-null   int64
#  3   chest pain type      1048 non-null   int64
#  4   resting bps          1048 non-null   int64
#  5   cholesterol          1048 non-null   float64
#  6   fasting blood sugar  1048 non-null   int64
#  7   resting ecg          1048 non-null   int64
#  8   max heart rate       1048 non-null   int64
#  9   exercise angina      1048 non-null   int64
#  10  oldpeak              1048 non-null   float64
#  11  ST slope             1048 non-null   int64
#  12  target               1048 non-null   int64
# dtypes: float64(2), int64(11)
# memory usage: 106.6 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# age                    0
# sex                    0
# chest pain type        0
# resting bps            0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         Unnamed: 0          age          sex  chest pain type  resting bps  \
# count  1048.000000  1048.000000  1048.000000      1048.000000  1048.000000
# mean    390.841603    53.325382     0.734733         2.817748   132.613550
# std     307.916633     9.397822     0.441686         1.118649    17.367605
# min       0.000000    28.000000     0.000000         1.000000    92.000000
# 25%     130.750000    46.000000     0.000000         2.000000   120.000000
# 50%     262.000000    54.000000     1.000000         3.000000   130.000000
# 75%     657.250000    60.000000     1.000000         4.000000   140.000000
# max    1189.000000    77.000000     1.000000         4.000000   200.000000
#
#        cholesterol  fasting blood sugar  resting ecg  max heart rate  \
# count  1048.000000          1048.000000  1048.000000     1048.000000
# mean    245.172710             0.162214     0.606870      142.918893
# std      57.101359             0.368823     0.763313       24.427115
# min      85.000000             0.000000     0.000000       69.000000
# 25%     208.000000             0.000000     0.000000      125.000000
# 50%     239.000000             0.000000     0.000000      144.000000
# 75%     275.000000             0.000000     1.000000      162.000000
# max     603.000000             1.000000     2.000000      202.000000
#
#        exercise angina      oldpeak     ST slope       target
# count      1048.000000  1048.000000  1048.000000  1048.000000
# mean          0.368321     0.942366     1.532443     0.496183
# std           0.482579     1.100429     0.611023     0.500224
# min           0.000000    -0.100000     0.000000     0.000000
# 25%           0.000000     0.000000     1.000000     0.000000
# 50%           0.000000     0.600000     2.000000     0.000000
# 75%           1.000000     1.600000     2.000000     1.000000
# max           1.000000     6.200000     3.000000     1.000000

# %%
df.drop(columns='Unnamed: 0',axis = 1, inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1048 non-null   int64
#  1   sex                  1048 non-null   int64
#  2   chest pain type      1048 non-null   int64
#  3   resting bps          1048 non-null   int64
#  4   cholesterol          1048 non-null   float64
#  5   fasting blood sugar  1048 non-null   int64
#  6   resting ecg          1048 non-null   int64
#  7   max heart rate       1048 non-null   int64
#  8   exercise angina      1048 non-null   int64
#  9   oldpeak              1048 non-null   float64
#  10  ST slope             1048 non-null   int64
#  11  target               1048 non-null   int64
# dtypes: float64(2), int64(10)
# memory usage: 98.4 KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1048 non-null   int64
#  1   sex                  1048 non-null   int64
#  2   chest pain type      1048 non-null   int64
#  3   resting bps          1048 non-null   int64
#  4   cholesterol          1048 non-null   float64
#  5   fasting blood sugar  1048 non-null   int64
#  6   resting ecg          1048 non-null   int64
#  7   max heart rate       1048 non-null   int64
#  8   exercise angina      1048 non-null   int64
#  9   oldpeak              1048 non-null   float64
#  10  ST slope             1048 non-null   int64
#  11  target               1048 non-null   int64
# dtypes: float64(2), int64(10)
# memory usage: 98.4 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'chest pain type', 'resting bps', 'cholesterol',
#        'fasting blood sugar', 'resting ecg', 'max heart rate',
#        'exercise angina', 'oldpeak', 'ST slope', 'target'],
#       dtype='object')

# %%
columns = ['age', 'resting bps', 'cholesterol','max heart rate']
for column in columns:
    if df[column].dtype == 'float64' or df[column].dtype == 'int64':
        fig, (ax_box, ax_hist) = plt.subplots(1, 2, figsize=(10, 5))

        ax_box.boxplot(df[column], vert=False, whis=1.5)
        ax_box.set_xlabel('Value')
        ax_box.set_title(f'{column} Box')

        sns.histplot(df[column], bins=50, color='blue', kde=True, ax=ax_hist)
        ax_hist.set_xlabel('Value')
        ax_hist.set_ylabel('Frequency')
        ax_hist.set_title(f'{column} dist')

        # Show plot
        plt.tight_layout()
        plt.show()

# %%
filter_data=pd.DataFrame()
for column in columns:
    if df[column].dtype=='float64' or df[column].dtype == 'int64':
        filter_data[column]=df[column]
print(filter_data.info())
for column in filter_data.columns:
    Q1 = filter_data[column].quantile(0.25)
    Q3 = filter_data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[column] = filter_data[(filter_data[column] >= lower_bound) & (filter_data[column] <= upper_bound)][column]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1048 non-null   int64
#  1   resting bps     1048 non-null   int64
#  2   cholesterol     1048 non-null   float64
#  3   max heart rate  1048 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 32.9 KB
# None

# %%
columns = ['age', 'resting bps', 'cholesterol','max heart rate']
for column in columns:
    if df[column].dtype == 'float64' or df[column].dtype == 'int64':
        fig, (ax_box, ax_hist) = plt.subplots(1, 2, figsize=(10, 5))

        ax_box.boxplot(df[column], vert=False, whis=1.5)
        ax_box.set_xlabel('Value')
        ax_box.set_title(f'{column} Box')

        sns.histplot(df[column], bins=50, color='blue', kde=True, ax=ax_hist)
        ax_hist.set_xlabel('Value')
        ax_hist.set_ylabel('Frequency')
        ax_hist.set_title(f'{column} dist')

        # Show plot
        plt.tight_layout()
        plt.show()

# %%
sex = df['sex'].value_counts().reset_index()
sex
# Out:
#    sex  count
# 0    1    770
# 1    0    278

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='sex', y='count', data=sex)

# Add title and labels
plt.title('Counts of Sex')
plt.xlabel('Sex')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
df
# Out:
#       age  sex  chest pain type  resting bps  cholesterol  \
# 0      40    1                2        140.0        289.0
# 1      49    0                3        160.0        180.0
# 2      37    1                2        130.0        283.0
# 3      48    0                4        138.0        214.0
# 4      54    1                3        150.0        195.0
# ...   ...  ...              ...          ...          ...
# 1043   68    0                3        120.0        211.0
# 1044   44    0                3        108.0        141.0
# 1045   52    1                1        128.0        255.0
# 1046   59    1                4        160.0        273.0
# 1047   54    1                1        120.0        188.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0           172.0                0
# 1                       0            0           156.0                0
# 2                       0            1            98.0                0
# 3                       0            0           108.0                1
# 4                       0            0           122.0                0
# ...                   ...          ...             ...              ...
# 1043                    0            0           115.0                0
# 1044                    0            1           175.0                0
# 1045                    0            1           161.0                1
# 1046                    0            0           125.0                0
# 1047                    0            1           113.0                0
#
#       oldpeak  ST slope  target
# 0         0.0         1       0
# 1         1.0         2       1
# 2         0.0         1       0
# 3         1.5         2       1
# 4         0.0         1       0
# ...       ...       ...     ...
# 1043      1.5         1       1
# 1044      0.6         1       1
# 1045      0.0         2       0
# 1046      0.0         2       0
# 1047      1.4         1       0
#
# [1048 rows x 12 columns]

# %%
sex_target = df['sex'].groupby(df['target']).value_counts().reset_index()

# %%
sex_target
# Out:
#    target  sex  count
# 0       0    1    362
# 1       0    0    166
# 2       1    1    408
# 3       1    0    112

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='target', y='count', hue='sex', data=sex_target)

# Add title and labels
plt.title('Counts of Sex within Each Target Group')
plt.xlabel('Target')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
chest_pain_type = df['chest pain type'].value_counts().reset_index()
chest_pain_type
# Out:
#    chest pain type  count
# 0                4    393
# 1                3    255
# 2                2    216
# 3                1    184

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='chest pain type', y='count', data=chest_pain_type)

# Add title and labels
plt.title('Counts of chest pain type')
plt.xlabel('chest_pain_type')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
df.head()
# Out:
#    age  sex  chest pain type  resting bps  cholesterol  fasting blood sugar  \
# 0   40    1                2        140.0        289.0                    0
# 1   49    0                3        160.0        180.0                    0
# 2   37    1                2        130.0        283.0                    0
# 3   48    0                4        138.0        214.0                    0
# 4   54    1                3        150.0        195.0                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0           172.0                0      0.0         1       0
# 1            0           156.0                0      1.0         2       1
# 2            1            98.0                0      0.0         1       0
# 3            0           108.0                1      1.5         2       1
# 4            0           122.0                0      0.0         1       0

# %%
corr = df.corr()

# Create a heatmap with more details
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, linecolor='black')

# Add title and adjust labels
plt.title('Correlation Matrix of Features', size=16)
plt.xticks(size=12)
plt.yticks(size=12, rotation=0)

# Show the plot
plt.show()

# %%
X = df.drop('target',axis = 1)
y = df['target']

# %%
X
# Out:
#       age  sex  chest pain type  resting bps  cholesterol  \
# 0      40    1                2        140.0        289.0
# 1      49    0                3        160.0        180.0
# 2      37    1                2        130.0        283.0
# 3      48    0                4        138.0        214.0
# 4      54    1                3        150.0        195.0
# ...   ...  ...              ...          ...          ...
# 1043   68    0                3        120.0        211.0
# 1044   44    0                3        108.0        141.0
# 1045   52    1                1        128.0        255.0
# 1046   59    1                4        160.0        273.0
# 1047   54    1                1        120.0        188.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0           172.0                0
# 1                       0            0           156.0                0
# 2                       0            1            98.0                0
# 3                       0            0           108.0                1
# 4                       0            0           122.0                0
# ...                   ...          ...             ...              ...
# 1043                    0            0           115.0                0
# 1044                    0            1           175.0                0
# 1045                    0            1           161.0                1
# 1046                    0            0           125.0                0
# 1047                    0            1           113.0                0
#
#       oldpeak  ST slope
# 0         0.0         1
# 1         1.0         2
# 2         0.0         1
# 3         1.5         2
# 4         0.0         1
# ...       ...       ...
# 1043      1.5         1
# 1044      0.6         1
# 1045      0.0         2
# 1046      0.0         2
# 1047      1.4         1
#
# [1048 rows x 11 columns]

# %%
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 1043    1
# 1044    1
# 1045    0
# 1046    0
# 1047    0
# Name: target, Length: 1048, dtype: int64

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_, y_train, y_ = train_test_split(X,y,test_size=0.2,random_state=43)
X_valid, X_test, y_valid, y_test = train_test_split(X_,y_,test_size=0.5,random_state=43)

# %%
X_train.shape
# Out:
# (838, 11)

# %%
X_test.shape
# Out:
# (105, 11)

# %%
model = Sequential([
    Dense(256, input_shape=(11,), activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.2),
    Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.2),
    Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.2),
    Dense(4, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 256)                 │           3,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4)                   │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 4)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 40,233 (157.16 KB)
#  Trainable params: 40,233 (157.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.5139 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5084 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5196 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4847 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5028 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5213 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5169 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 8/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5256 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 9/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5236 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 10/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5355 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 11/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4958 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 12/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5040 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 13/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5048 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 14/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5085 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 15/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5204 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 16/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5126 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 17/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5021 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 18/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5544 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 19/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5298 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 20/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5240 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 21/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5348 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 22/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5121 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 23/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5359 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 24/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5264 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 25/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5238 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 26/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5106 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 27/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4989 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 28/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5337 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 29/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5166 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 30/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5125 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 31/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5103 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 32/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5157 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 33/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5095 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 34/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5370 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 35/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5286 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 36/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5083 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 37/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5240 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 38/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5066 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 39/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5041 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 40/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5102 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 41/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5108 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 42/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5141 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 43/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5185 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 44/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5383 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 45/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5188 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 46/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5102 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 47/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5034 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 48/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5101 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 49/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5088 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 50/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5315 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 51/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5162 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 52/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5284 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 53/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5183 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 54/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4921 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 55/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5185 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 56/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5260 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 57/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5209 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 58/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4958 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 59/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5131 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 60/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5105 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 61/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5255 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 62/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5250 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 63/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5130 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 64/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5224 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 65/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5328 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 66/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5130 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 67/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5014 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 68/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5378 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 69/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5138 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 70/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5198 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 71/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4963 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 72/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5179 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 73/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4936 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 74/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5473 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 75/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5181 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 76/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5124 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 77/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4819 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 78/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5050 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 79/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5297 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 80/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4940 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 81/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5250 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 82/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5015 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 83/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5244 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 84/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5186 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 85/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5259 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 86/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5110 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 87/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5153 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 88/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5165 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 89/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4976 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 90/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5126 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 91/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5141 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 92/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5018 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 93/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5208 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 94/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5082 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 95/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5172 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 96/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5239 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 97/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5233 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 98/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5185 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 99/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5437 - loss: nan - val_accuracy: 0.4190 - val_loss: nan
# Epoch 100/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4962 - loss: nan - val_accuracy: 0.4190 - val_loss: nan

# %%
# Extract accuracy values
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(train_accuracy) + 1)

# Plot accuracy values
plt.plot(epochs, train_accuracy, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}, Test Accuracy:{accuracy}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4735 - loss: nan
# Test Loss: nan, Test Accuracy:0.48571428656578064

# %%
y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int)
y_pred_flat = np.ravel(y_pred)
y_test_flat = np.ravel(y_test)
conf_matrix = confusion_matrix(y_test_flat, y_pred_flat)

print("Confusion Matrix:")
print(conf_matrix)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Confusion Matrix:
# [[51  0]
#  [54  0]]

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %%
print("\nClassification Report:")
print(classification_report(y_test_flat, y_pred_flat))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.65        51
#            1       0.00      0.00      0.00        54
#
#     accuracy                           0.49       105
#    macro avg       0.24      0.50      0.33       105
# weighted avg       0.24      0.49      0.32       105
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
